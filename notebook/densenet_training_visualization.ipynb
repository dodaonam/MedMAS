# %% [markdown]
# # DenseNet121 Training Visualization
#
# This notebook reads saved training artifacts and regenerates visualization figures. It does not run model training.

# %%
from pathlib import Path
import sys

ROOT = Path.cwd().resolve()
if not (ROOT / "src").exists():
    ROOT = ROOT.parent
sys.path.insert(0, str(ROOT / "src"))

from train_densenet import resolve_run_dir
from visualize_densenet.report import generate_visualization_report

# %%
RUN_BASE_DIR = ROOT / "artifacts" / "training" / "densenet121"
RUN_DIR = resolve_run_dir(RUN_BASE_DIR)
MANIFEST_PATH = ROOT / "artifacts" / "preprocess" / "split_manifest.csv"
TARGET_LABELS_PATH = ROOT / "artifacts" / "preprocess" / "target_labels.json"

generated_paths = generate_visualization_report(
    run_dir=RUN_DIR,
    manifest_path=MANIFEST_PATH,
    target_labels_path=TARGET_LABELS_PATH,
    root=ROOT,
)
len(generated_paths), generated_paths[:5]
